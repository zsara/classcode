# %% [markdown]
# ## ***Plotting brightness temperatures in a Lambert Conformal Conic map projection***

# %% [markdown]
# In this notebook we're going to continue working with http://clouds.eos.ubc.ca/~phil/Downloads/a301/MYD021KM.A2005188.0405.005.2009232180906.h5.  We will also need to go to Laadsweb and do a wildcard search on
# the filename:
#
# `MYD03.A2005188.0405.*`
#
# which will produce the geometry file which can be downloaded and converted to hdf5 to get
#
# http://clouds.eos.ubc.ca/~phil/Downloads/a301/MYD03.A2005188.0405.005.2009231234639.h5
#
# The MYD03 file contains the lat/lon for every
# pixel and is described at http://modaps.nascom.nasa.gov/services/about/products/MYD03.html

# %% [markdown]
# Recall that we read and converted the channel 31 radiance:

# %%
from __future__ import print_function
import os,site
import glob
import h5py
from IPython.display import Image
import numpy as np
from matplotlib import pyplot as plt
#
# add the lib folder to the path assuming it is on the same
# level as the notebooks folder
#
libdir=os.path.abspath('C:/GitHub/classcode/lib')
site.addsitedir(libdir)
import h5dump

# %% [markdown]
# the glob function finds a file using a wildcard to save typing (google: python glob wildcard)

# %%
h5_filename=glob.glob('C:/GitHub/classcode/lib/MOD021KM.A2005199.0215.005.2010155072656.h5')
print("found {}".format(h5_filename))
# Out:
# found ['C:/GitHub/classcode/lib/MOD021KM.A2005199.0215.005.2010155072656.h5']

# %%
h5_file=h5py.File(h5_filename[0])

# %% [markdown]
# **Read the radiance data from MODIS_SWATH_Type_L1B/Data Fields/EV_1KM_Emissive**

# %% [markdown]
# **note that channel 31 occurs at index value 10**

# %%
index31=10

# %% [markdown]
# **the data is stored as unsigned, 2 byte integers which can hold values from 0 to $2^{16}$ - 1 = 65,535 **

# %%
chan31=h5_file['MODIS_SWATH_Type_L1B']['Data Fields']['EV_1KM_Emissive'][index31,:,:]
print(chan31.shape,chan31.dtype)
# Out:
# (2040L, 1354L) >u2

# %%
chan31[:3,:3]
# Out:
# array([[11064, 11347, 11630],
#        [11071, 11268, 11596],
#        [11251, 11352, 11618]], dtype=uint16)

# %% [markdown]
# ** we need to apply a
# scale and offset to convert to radiance (the netcdf module did this for us automatically**

# %% [markdown]
# $Data = (RawData - offset) \times scale$
#
# this information is included in the attributes of each variable.
#
# (see page 36 of the [Modis users guide](http://clouds.eos.ubc.ca/~phil/courses/atsc301/text/modis_users_guide.pdf) )

# %% [markdown]
# **here is the scale for all 16 channels**

# %%
scale=h5_file['MODIS_SWATH_Type_L1B']['Data Fields']['EV_1KM_Emissive'].attrs['radiance_scales'][...]
print(scale)
# Out:
# [  6.26239853e-05   3.14951013e-03   6.92159738e-05   7.91039784e-05
#    3.15561410e-05   5.63982067e-05   1.17557298e-04   1.92449734e-04
#    5.32486942e-04   4.06323437e-04   8.40021996e-04   7.29697582e-04
#    2.62263871e-04   2.00695824e-04   1.76708272e-04   1.18338568e-04]

# %% [markdown]
# **and here is the offset for 16 channels**

# %%
offset=h5_file['MODIS_SWATH_Type_L1B']['Data Fields']['EV_1KM_Emissive'].attrs['radiance_offsets'][...]
print(offset)
# Out:
# [ 2730.58349609  2730.58349609  2730.58349609  2730.58349609  1077.44482422
#   1560.33337402  2730.58325195  2317.48828125  2730.58349609  1560.33325195
#   1577.33972168  1658.22131348  2501.29760742  2501.29760742  2501.29785156
#   2501.29785156]

# %%
chan31=(chan31 - offset[index31])*scale[index31]

# %% [markdown]
# now convert this to brightness temperature

# %%
def planckInvert(wavel,Llambda):
    """input wavelength in microns and Llambda in W/m^2/micron/sr, output
    output brightness temperature in K  (note that we've remove the factor
    of pi because we are working with radiances, not fluxes)
    """
    c=2.99792458e+08  #m/s -- speed of light in vacumn
    h=6.62606876e-34  #J s  -- Planck's constant
    kb=1.3806503e-23  # J/K  -- Boltzman's constant
    c1=2.*h*c**2.
    c2=h*c/kb

    Llambda=Llambda*1.e6  #convert to W/m^2/m/sr
    wavel=wavel*1.e-6  #convert wavelength to m
    Tbright=c2/(wavel*np.log(c1/(wavel**5.*Llambda) + 1.))
    
    return Tbright

# %%
chan31_Tbright=planckInvert(11.02, chan31)

# %%
# %matplotlib inline

# %% [markdown]
# **histogram the calibrated radiances and show that they lie between
# 0-10 $W\,m^{-2}\,\mu m^{-1}\,sr^{-1}$ **

# %%
import matplotlib.pyplot as plt
out=plt.hist(chan31_Tbright.flat)

# %% [markdown]
# **Read MYD03 Geolocation Fields**

# %% [markdown]
# note that the longitude and latitude arrays are (406,271) while the actual
# data are (2030,1354).   These lat/lon arrays show only every fifth row and column.
# We need to get the full lat/lon arrays from the MYD03 file

# %%
geom_filename=glob.glob('C:/GitHub/classcode/lib/MOD03.A2005199.0215.005.2010154180154.h5')
print("found {}".format(h5_filename))
# Out:
# found ['C:/GitHub/classcode/lib/MOD021KM.A2005199.0215.005.2010155072656.h5']

# %%
geom_h5=h5py.File(geom_filename[0])

# %%
h5dump.dumph5(geom_h5)
# Out:
# item name:  Average Temperatures <HDF5 dataset "Average Temperatures": shape (1,), type "|V24">
#     _FillValue: -999.0
#     TITLE: Average Temperatures
#     CLASS: TABLE
#     VERSION: 1.0
#     FIELD_0_NAME: TA_RC_SMIR_CFPA
#     units:TA_RC_SMIR_CFPA: Kelvin
#     valid_range:TA_RC_SMIR_CFPA: [  50.  118.]
#     FIELD_1_NAME: TP_AO_SMIR_OBJ
#     units:TP_AO_SMIR_OBJ: Celsius
#     valid_range:TP_AO_SMIR_OBJ: [-23.  87.]
#     FIELD_2_NAME: TP_MF_CALBKHD_SR
#     units:TP_MF_CALBKHD_SR: Celsius
#     valid_range:TP_MF_CALBKHD_SR: [-22.  87.]
#     FIELD_3_NAME: TP_MF_Z_BKHD_BB
#     units:TP_MF_Z_BKHD_BB: Celsius
#     valid_range:TP_MF_Z_BKHD_BB: [-22.  87.]
#     FIELD_4_NAME: TP_SA_RCT1_MIR
#     units:TP_SA_RCT1_MIR: Celsius
#     valid_range:TP_SA_RCT1_MIR: [-23.  87.]
#     FIELD_5_NAME: TP_SR_SNOUT
#     units:TP_SR_SNOUT: Celsius
#     valid_range:TP_SR_SNOUT: [-23.  87.]
#     HDF4_OBJECT_TYPE: Vdata
#     HDF4_OBJECT_NAME: Average Temperatures
#     HDF4_REF_NUM: 2100
# item name:  Average Temperatures_t <HDF5 named type "Average Temperatures_t" (dtype |V24)>
# item name:  EV center time <HDF5 dataset "EV center time": shape (204,), type ">f8">
#     DIMENSION_NAMELIST: ['/HDF4_DIMGROUP/nscans']
#     units: seconds
#     _FillValue: -2000000000.0
#     HDF4_OBJECT_TYPE: SDS
#     HDF4_OBJECT_NAME: EV center time
#     HDF4_REF_NUM: 2056
# item name:  EV frames <HDF5 dataset "EV frames": shape (204,), type ">u2">
#     DIMENSION_NAMELIST: ['/HDF4_DIMGROUP/nscans']
#     valid_range: [   0 1400]
#     HDF4_OBJECT_TYPE: SDS
#     HDF4_OBJECT_NAME: EV frames
#     HDF4_REF_NUM: 2044
# item name:  EV start time <HDF5 dataset "EV start time": shape (204,), type ">f8">
#     DIMENSION_NAMELIST: ['/HDF4_DIMGROUP/nscans']
#     units: seconds
#     _FillValue: -2000000000.0
#     HDF4_OBJECT_TYPE: SDS
#     HDF4_OBJECT_NAME: EV start time
#     HDF4_REF_NUM: 2050
# item name:  Focal_length <HDF5 dataset "Focal_length": shape (37,), type ">f8">
#     DIMENSION_NAMELIST: ['/HDF4_DIMGROUP/numbands']
#     units: meters
#     HDF4_OBJECT_TYPE: SDS
#     HDF4_OBJECT_NAME: Focal_length
#     HDF4_REF_NUM: 2088
# item name:  Geo scan quality <HDF5 dataset "Geo scan quality": shape (204, 4), type "|i1">
#     _FillValue: -127
#     DIMENSION_NAMELIST: ['/HDF4_DIMGROUP/nscans' '/HDF4_DIMGROUP/numqual']
#     HDF4_OBJECT_TYPE: SDS
#     HDF4_OBJECT_NAME: Geo scan quality
#     HDF4_REF_NUM: 2068
# item name:  HDF4_DIMGROUP <HDF5 group "/HDF4_DIMGROUP" (0 members)>
# item name:  L1 scan quality <HDF5 dataset "L1 scan quality": shape (204, 4), type ">i4">
#     DIMENSION_NAMELIST: ['/HDF4_DIMGROUP/nscans' '/HDF4_DIMGROUP/numqual']
#     _FillValue: -1
#     HDF4_OBJECT_TYPE: SDS
#     HDF4_OBJECT_NAME: L1 scan quality
#     HDF4_REF_NUM: 2066
# item name:  MODIS_Swath_Type_GEO <HDF5 group "/MODIS_Swath_Type_GEO" (3 members)>
#     HDF4_OBJECT_TYPE: Vgroup
#     HDF4_OBJECT_NAME: MODIS_Swath_Type_GEO
#     HDF4_REF_NUM: 2
# item name:  MODIS_Swath_Type_GEO/Data Fields <HDF5 group "/MODIS_Swath_Type_GEO/Data Fields" (8 members)>
#     HDF4_OBJECT_TYPE: Vgroup
#     HDF4_OBJECT_NAME: Data Fields
#     HDF4_REF_NUM: 409
# item name:  MODIS_Swath_Type_GEO/Data Fields/Height <HDF5 dataset "Height": shape (2040, 1354), type ">i2">
#     DIMENSION_NAMELIST: ['/HDF4_DIMGROUP/nscans*10:MODIS_Swath_Type_GEO'
#  '/HDF4_DIMGROUP/mframes:MODIS_Swath_Type_GEO']
#     units: meters
#     valid_range: [ -400 10000]
#     _FillValue: -32767
#     HDF4_OBJECT_TYPE: SDS
#     HDF4_OBJECT_NAME: Height
#     HDF4_REF_NUM: 410
# item name:  MODIS_Swath_Type_GEO/Data Fields/Land_SeaMask <HDF5 dataset "Land_SeaMask": shape (2040, 1354), type "|u1">
#     DIMENSION_NAMELIST: ['/HDF4_DIMGROUP/nscans*10:MODIS_Swath_Type_GEO'
#  '/HDF4_DIMGROUP/mframes:MODIS_Swath_Type_GEO']
#     _FillValue: 221
#     HDF4_OBJECT_TYPE: SDS
#     HDF4_OBJECT_NAME: Land/SeaMask
#     HDF4_REF_NUM: 1633
# item name:  MODIS_Swath_Type_GEO/Data Fields/Range <HDF5 dataset "Range": shape (2040, 1354), type ">u2">
#     units: meters
#     valid_range: [27000 65535]
#     _FillValue: 0
#     scale_factor: 25.0
#     HDF4_OBJECT_TYPE: SDS
#     DIMENSION_NAMELIST: ['/HDF4_DIMGROUP/nscans*10:MODIS_Swath_Type_GEO'
#  '/HDF4_DIMGROUP/mframes:MODIS_Swath_Type_GEO']
#     HDF4_OBJECT_NAME: Range
#     HDF4_REF_NUM: 1021
# item name:  MODIS_Swath_Type_GEO/Data Fields/SensorAzimuth <HDF5 dataset "SensorAzimuth": shape (2040, 1354), type ">i2">
#     DIMENSION_NAMELIST: ['/HDF4_DIMGROUP/nscans*10:MODIS_Swath_Type_GEO'
#  '/HDF4_DIMGROUP/mframes:MODIS_Swath_Type_GEO']
#     units: degrees
#     valid_range: [-18000  18000]
#     _FillValue: -32767
#     scale_factor: 0.01
#     HDF4_OBJECT_TYPE: SDS
#     HDF4_OBJECT_NAME: SensorAzimuth
#     HDF4_REF_NUM: 817
# item name:  MODIS_Swath_Type_GEO/Data Fields/SensorZenith <HDF5 dataset "SensorZenith": shape (2040, 1354), type ">i2">
#     DIMENSION_NAMELIST: ['/HDF4_DIMGROUP/nscans*10:MODIS_Swath_Type_GEO'
#  '/HDF4_DIMGROUP/mframes:MODIS_Swath_Type_GEO']
#     units: degrees
#     valid_range: [    0 18000]
#     _FillValue: -32767
#     scale_factor: 0.01
#     HDF4_OBJECT_TYPE: SDS
#     HDF4_OBJECT_NAME: SensorZenith
#     HDF4_REF_NUM: 613
# item name:  MODIS_Swath_Type_GEO/Data Fields/SolarAzimuth <HDF5 dataset "SolarAzimuth": shape (2040, 1354), type ">i2">
#     DIMENSION_NAMELIST: ['/HDF4_DIMGROUP/nscans*10:MODIS_Swath_Type_GEO'
#  '/HDF4_DIMGROUP/mframes:MODIS_Swath_Type_GEO']
#     units: degrees
#     valid_range: [-18000  18000]
#     _FillValue: -32767
#     scale_factor: 0.01
#     HDF4_OBJECT_TYPE: SDS
#     HDF4_OBJECT_NAME: SolarAzimuth
#     HDF4_REF_NUM: 1429
# item name:  MODIS_Swath_Type_GEO/Data Fields/SolarZenith <HDF5 dataset "SolarZenith": shape (2040, 1354), type ">i2">
#     DIMENSION_NAMELIST: ['/HDF4_DIMGROUP/nscans*10:MODIS_Swath_Type_GEO'
#  '/HDF4_DIMGROUP/mframes:MODIS_Swath_Type_GEO']
#     units: degrees
#     valid_range: [    0 18000]
#     _FillValue: -32767
#     scale_factor: 0.01
#     HDF4_OBJECT_TYPE: SDS
#     HDF4_OBJECT_NAME: SolarZenith
#     HDF4_REF_NUM: 1225
# item name:  MODIS_Swath_Type_GEO/Data Fields/gflags <HDF5 dataset "gflags": shape (2040, 1354), type "|u1">
#     DIMENSION_NAMELIST: ['/HDF4_DIMGROUP/nscans*10:MODIS_Swath_Type_GEO'
#  '/HDF4_DIMGROUP/mframes:MODIS_Swath_Type_GEO']
#     _FillValue: 255
#     HDF4_OBJECT_TYPE: SDS
#     HDF4_OBJECT_NAME: gflags
#     HDF4_REF_NUM: 1837
# item name:  MODIS_Swath_Type_GEO/Geolocation Fields <HDF5 group "/MODIS_Swath_Type_GEO/Geolocation Fields" (2 members)>
#     HDF4_OBJECT_TYPE: Vgroup
#     HDF4_OBJECT_NAME: Geolocation Fields
#     HDF4_REF_NUM: 3
# item name:  MODIS_Swath_Type_GEO/Geolocation Fields/Latitude <HDF5 dataset "Latitude": shape (2040, 1354), type ">f4">
#     DIMENSION_NAMELIST: ['/HDF4_DIMGROUP/nscans*10:MODIS_Swath_Type_GEO'
#  '/HDF4_DIMGROUP/mframes:MODIS_Swath_Type_GEO']
#     units: degrees
#     valid_range: [-90.  90.]
#     _FillValue: -999.0
#     HDF4_OBJECT_TYPE: SDS
#     HDF4_OBJECT_NAME: Latitude
#     HDF4_REF_NUM: 4
# item name:  MODIS_Swath_Type_GEO/Geolocation Fields/Longitude <HDF5 dataset "Longitude": shape (2040, 1354), type ">f4">
#     DIMENSION_NAMELIST: ['/HDF4_DIMGROUP/nscans*10:MODIS_Swath_Type_GEO'
#  '/HDF4_DIMGROUP/mframes:MODIS_Swath_Type_GEO']
#     units: degrees
#     valid_range: [-180.  180.]
#     _FillValue: -999.0
#     HDF4_OBJECT_TYPE: SDS
#     HDF4_OBJECT_NAME: Longitude
#     HDF4_REF_NUM: 205
# item name:  MODIS_Swath_Type_GEO/Swath Attributes <HDF5 group "/MODIS_Swath_Type_GEO/Swath Attributes" (0 members)>
#     HDF4_OBJECT_TYPE: Vgroup
#     HDF4_OBJECT_NAME: Swath Attributes
#     HDF4_REF_NUM: 2041
# item name:  Mirror side <HDF5 dataset "Mirror side": shape (204,), type ">u2">
#     DIMENSION_NAMELIST: ['/HDF4_DIMGROUP/nscans']
#     valid_range: [0 1]
#     _FillValue: 65535
#     HDF4_OBJECT_TYPE: SDS
#     HDF4_OBJECT_NAME: Mirror side
#     HDF4_REF_NUM: 2058
# item name:  Moon Vector <HDF5 dataset "Moon Vector": shape (204, 3), type ">f4">
#     DIMENSION_NAMELIST: ['/HDF4_DIMGROUP/nscans' '/HDF4_DIMGROUP/vecdim']
#     _FillValue: 9.96921e+36
#     HDF4_OBJECT_TYPE: SDS
#     HDF4_OBJECT_NAME: Moon Vector
#     HDF4_REF_NUM: 2064
# item name:  SD Sun azimuth <HDF5 dataset "SD Sun azimuth": shape (204,), type ">f4">
#     units: radians
#     DIMENSION_NAMELIST: ['/HDF4_DIMGROUP/nscans']
#     _FillValue: 9.96921e+36
#     HDF4_OBJECT_TYPE: SDS
#     HDF4_OBJECT_NAME: SD Sun azimuth
#     HDF4_REF_NUM: 2062
# item name:  SD Sun zenith <HDF5 dataset "SD Sun zenith": shape (204,), type ">f4">
#     DIMENSION_NAMELIST: ['/HDF4_DIMGROUP/nscans']
#     units: radians
#     _FillValue: 9.96921e+36
#     HDF4_OBJECT_TYPE: SDS
#     HDF4_OBJECT_NAME: SD Sun zenith
#     HDF4_REF_NUM: 2060
# item name:  SD frames <HDF5 dataset "SD frames": shape (204,), type ">u2">
#     HDF4_OBJECT_TYPE: SDS
#     DIMENSION_NAMELIST: ['/HDF4_DIMGROUP/nscans']
#     HDF4_OBJECT_NAME: SD frames
#     HDF4_REF_NUM: 2046
# item name:  SD start time <HDF5 dataset "SD start time": shape (204,), type ">f8">
#     DIMENSION_NAMELIST: ['/HDF4_DIMGROUP/nscans']
#     units: seconds
#     _FillValue: -2000000000.0
#     HDF4_OBJECT_TYPE: SDS
#     HDF4_OBJECT_NAME: SD start time
#     HDF4_REF_NUM: 2052
# item name:  SV frames <HDF5 dataset "SV frames": shape (204,), type ">u2">
#     DIMENSION_NAMELIST: ['/HDF4_DIMGROUP/nscans']
#     HDF4_OBJECT_TYPE: SDS
#     HDF4_OBJECT_NAME: SV frames
#     HDF4_REF_NUM: 2048
# item name:  SV start time <HDF5 dataset "SV start time": shape (204,), type ">f8">
#     DIMENSION_NAMELIST: ['/HDF4_DIMGROUP/nscans']
#     units: seconds
#     _FillValue: -2000000000.0
#     HDF4_OBJECT_TYPE: SDS
#     HDF4_OBJECT_NAME: SV start time
#     HDF4_REF_NUM: 2054
# item name:  Scan Type <HDF5 dataset "Scan Type": shape (204, 10), type "|i1">
#     DIMENSION_NAMELIST: ['/HDF4_DIMGROUP/nscans']
#     HDF4_OBJECT_TYPE: SDS
#     HDF4_OBJECT_NAME: Scan Type
#     HDF4_REF_NUM: 2086
# item name:  Scan number <HDF5 dataset "Scan number": shape (204,), type ">i2">
#     DIMENSION_NAMELIST: ['/HDF4_DIMGROUP/nscans']
#     _FillValue: 0
#     HDF4_OBJECT_TYPE: SDS
#     HDF4_OBJECT_NAME: Scan number
#     HDF4_REF_NUM: 2042
# item name:  T_inst2ECR <HDF5 dataset "T_inst2ECR": shape (204, 3, 3), type ">f8">
#     valid_range: [-1.  1.]
#     DIMENSION_NAMELIST: ['/HDF4_DIMGROUP/nscans' '/HDF4_DIMGROUP/vecdim' '/HDF4_DIMGROUP/vecdim']
#     _FillValue: 9.96920996839e+36
#     HDF4_OBJECT_TYPE: SDS
#     HDF4_OBJECT_NAME: T_inst2ECR
#     HDF4_REF_NUM: 2074
# item name:  T_offset <HDF5 dataset "T_offset": shape (37,), type ">f8">
#     DIMENSION_NAMELIST: ['/HDF4_DIMGROUP/numbands']
#     units: frame sample time
#     HDF4_OBJECT_TYPE: SDS
#     HDF4_OBJECT_NAME: T_offset
#     HDF4_REF_NUM: 2096
# item name:  attitude_angles <HDF5 dataset "attitude_angles": shape (204, 3), type ">f8">
#     units: radians
#     _FillValue: 9.96920996839e+36
#     roll_element: 0
#     pitch_element: 1
#     yaw_element: 2
#     HDF4_OBJECT_TYPE: SDS
#     HDF4_OBJECT_NAME: attitude_angles
#     HDF4_REF_NUM: 2076
#     DIMENSION_NAMELIST: ['/HDF4_DIMGROUP/nscans' '/HDF4_DIMGROUP/vecdim']
# item name:  band_position <HDF5 dataset "band_position": shape (37,), type ">f8">
#     units: frame sample time
#     DIMENSION_NAMELIST: ['/HDF4_DIMGROUP/numbands']
#     HDF4_OBJECT_TYPE: SDS
#     HDF4_OBJECT_NAME: band_position
#     HDF4_REF_NUM: 2090
# item name:  detector_offsets <HDF5 dataset "detector_offsets": shape (37, 2), type ">f8">
#     units: meters
#     DIMENSION_NAMELIST: ['/HDF4_DIMGROUP/numbands']
#     scandim: 0
#     trackdim: 1
#     HDF4_OBJECT_TYPE: SDS
#     HDF4_OBJECT_NAME: detector_offsets
#     HDF4_REF_NUM: 2094
# item name:  detector_space <HDF5 dataset "detector_space": shape (37,), type ">f8">
#     DIMENSION_NAMELIST: ['/HDF4_DIMGROUP/numbands']
#     units: meters
#     HDF4_OBJECT_TYPE: SDS
#     HDF4_OBJECT_NAME: detector_space
#     HDF4_REF_NUM: 2092
# item name:  impulse_enc <HDF5 dataset "impulse_enc": shape (204, 25), type ">f8">
#     DIMENSION_NAMELIST: ['/HDF4_DIMGROUP/nscans' '/HDF4_DIMGROUP/numenc']
#     units: encoder pulses
#     valid_range: [     0.  16384.]
#     _FillValue: 9.96920996839e+36
#     HDF4_OBJECT_TYPE: SDS
#     HDF4_OBJECT_NAME: impulse_enc
#     HDF4_REF_NUM: 2082
# item name:  impulse_time <HDF5 dataset "impulse_time": shape (204, 25), type ">f8">
#     DIMENSION_NAMELIST: ['/HDF4_DIMGROUP/nscans' '/HDF4_DIMGROUP/numenc']
#     units: seconds
#     valid_range: [ 0.   1.5]
#     _FillValue: 9.96920996839e+36
#     HDF4_OBJECT_TYPE: SDS
#     HDF4_OBJECT_NAME: impulse_time
#     HDF4_REF_NUM: 2084
# item name:  num_impulse <HDF5 dataset "num_impulse": shape (204,), type "|u1">
#     DIMENSION_NAMELIST: ['/HDF4_DIMGROUP/nscans']
#     valid_range: [ 0 25]
#     HDF4_OBJECT_TYPE: SDS
#     HDF4_OBJECT_NAME: num_impulse
#     HDF4_REF_NUM: 2080
# item name:  num_samples <HDF5 dataset "num_samples": shape (37,), type ">u2">
#     DIMENSION_NAMELIST: ['/HDF4_DIMGROUP/numbands']
#     HDF4_OBJECT_TYPE: SDS
#     HDF4_OBJECT_NAME: num_samples
#     HDF4_REF_NUM: 2098
# item name:  orb_pos <HDF5 dataset "orb_pos": shape (204, 3), type ">f8">
#     DIMENSION_NAMELIST: ['/HDF4_DIMGROUP/nscans' '/HDF4_DIMGROUP/vecdim']
#     units: meters
#     valid_range: [-7200000.  7200000.]
#     _FillValue: 9.96920996839e+36
#     HDF4_OBJECT_TYPE: SDS
#     HDF4_OBJECT_NAME: orb_pos
#     HDF4_REF_NUM: 2070
# item name:  orb_vel <HDF5 dataset "orb_vel": shape (204, 3), type ">f8">
#     DIMENSION_NAMELIST: ['/HDF4_DIMGROUP/nscans' '/HDF4_DIMGROUP/vecdim']
#     units: meters per second
#     valid_range: [-7600.  7600.]
#     _FillValue: 9.96920996839e+36
#     HDF4_OBJECT_TYPE: SDS
#     HDF4_OBJECT_NAME: orb_vel
#     HDF4_REF_NUM: 2072
# item name:  sun_ref <HDF5 dataset "sun_ref": shape (204, 3), type ">f4">
#     DIMENSION_NAMELIST: ['/HDF4_DIMGROUP/nscans' '/HDF4_DIMGROUP/vecdim']
#     valid_range: [-1.  1.]
#     _FillValue: 9.96921e+36
#     HDF4_OBJECT_TYPE: SDS
#     HDF4_OBJECT_NAME: sun_ref
#     HDF4_REF_NUM: 2078
# -------------------
# attributes for the root file
# -------------------
# attribute name:  HDFEOSVersion_GLOSDS --- value:  HDFEOS_V2.9
# attribute name:  StructMetadata.0_GLOSDS --- value:  GROUP=SwathStructure
# 	GROUP=SWATH_1
# 		SwathName="MODIS_Swath_Type_GEO"
# 		GROUP=Dimension
# 			OBJECT=Dimension_1
# 				DimensionName="nscans*10"
# 				Size=2040
# 			END_OBJECT=Dimension_1
# 			OBJECT=Dimension_2
# 				DimensionName="mframes"
# 				Size=1354
# 			END_OBJECT=Dimension_2
# 		END_GROUP=Dimension
# 		GROUP=DimensionMap
# 		END_GROUP=DimensionMap
# 		GROUP=IndexDimensionMap
# 		END_GROUP=IndexDimensionMap
# 		GROUP=GeoField
# 			OBJECT=GeoField_1
# 				GeoFieldName="Latitude"
# 				DataType=DFNT_FLOAT32
# 				DimList=("nscans*10","mframes")
# 			END_OBJECT=GeoField_1
# 			OBJECT=GeoField_2
# 				GeoFieldName="Longitude"
# 				DataType=DFNT_FLOAT32
# 				DimList=("nscans*10","mframes")
# 			END_OBJECT=GeoField_2
# 		END_GROUP=GeoField
# 		GROUP=DataField
# 			OBJECT=DataField_1
# 				DataFieldName="Height"
# 				DataType=DFNT_INT16
# 				DimList=("nscans*10","mframes")
# 			END_OBJECT=DataField_1
# 			OBJECT=DataField_2
# 				DataFieldName="SensorZenith"
# 				DataType=DFNT_INT16
# 				DimList=("nscans*10","mframes")
# 			END_OBJECT=DataField_2
# 			OBJECT=DataField_3
# 				DataFieldName="SensorAzimuth"
# 				DataType=DFNT_INT16
# 				DimList=("nscans*10","mframes")
# 			END_OBJECT=DataField_3
# 			OBJECT=DataField_4
# 				DataFieldName="Range"
# 				DataType=DFNT_UINT16
# 				DimList=("nscans*10","mframes")
# 			END_OBJECT=DataField_4
# 			OBJECT=DataField_5
# 				DataFieldName="SolarZenith"
# 				DataType=DFNT_INT16
# 				DimList=("nscans*10","mframes")
# 			END_OBJECT=DataField_5
# 			OBJECT=DataField_6
# 				DataFieldName="SolarAzimuth"
# 				DataType=DFNT_INT16
# 				DimList=("nscans*10","mframes")
# 			END_OBJECT=DataField_6
# 			OBJECT=DataField_7
# 				DataFieldName="Land/SeaMask"
# 				DataType=DFNT_UINT8
# 				DimList=("nscans*10","mframes")
# 			END_OBJECT=DataField_7
# 			OBJECT=DataField_8
# 				DataFieldName="gflags"
# 				DataType=DFNT_UINT8
# 				DimList=("nscans*10","mframes")
# 			END_OBJECT=DataField_8
# 		END_GROUP=DataField
# 		GROUP=MergedFields
# 		END_GROUP=MergedFields
# 	END_GROUP=SWATH_1
# END_GROUP=SwathStructure
# GROUP=GridStructure
# END_GROUP=GridStructure
# GROUP=PointStructure
# END_GROUP=PointStructure
# END
#
# attribute name:  Ephemeris Input Files.1_GLOSDS --- value:  LGID:AM1ATTN0:001:AM1ATTN0.A2005199.0000.001.2005199030345LGID:AM1EPHN0:001:AM1EPHN0.A2005199.0000.001.2005199030345UR:10:DsShESDTUR:UR:15:DsShSciServerUR:13:[GSF:DSSDSRV]:22:SC:AM1ANC.001:59341110UR:10:DsShESDTUR:UR:15:DsShSciServerUR:13:[GSF:DSSDSRV]:22:SC:AM1ANC.001:59345155N/AN/A
# attribute name:  Attitude Input Files.1_GLOSDS --- value:  LGID:AM1ATTN0:001:AM1ATTN0.A2005199.0000.001.2005199030345LGID:AM1EPHN0:001:AM1EPHN0.A2005199.0000.001.2005199030345UR:10:DsShESDTUR:UR:15:DsShSciServerUR:13:[GSF:DSSDSRV]:22:SC:AM1ANC.001:59341110UR:10:DsShESDTUR:UR:15:DsShSciServerUR:13:[GSF:DSSDSRV]:22:SC:AM1ANC.001:59345155N/AN/A
# attribute name:  CoreMetadata.0_GLOSDS --- value:
# GROUP                  = INVENTORYMETADATA
#   GROUPTYPE            = MASTERGROUP
#
#   GROUP                  = ECSDATAGRANULE
#
#     OBJECT                 = LOCALGRANULEID
#       NUM_VAL              = 1
#       VALUE                = "MOD03.A2005199.0215.005.2010154180154.hdf"
#     END_OBJECT             = LOCALGRANULEID
#
#     OBJECT                 = PRODUCTIONDATETIME
#       NUM_VAL              = 1
#       VALUE                = "2010-06-03T18:01:54.000Z"
#     END_OBJECT             = PRODUCTIONDATETIME
#
#     OBJECT                 = DAYNIGHTFLAG
#       NUM_VAL              = 1
#       VALUE                = "Day"
#     END_OBJECT             = DAYNIGHTFLAG
#
#     OBJECT                 = REPROCESSINGACTUAL
#       NUM_VAL              = 1
#       VALUE                = "reprocessed"
#     END_OBJECT             = REPROCESSINGACTUAL
#
#     OBJECT                 = LOCALVERSIONID
#       NUM_VAL              = 1
#       VALUE                = "5.0.0"
#     END_OBJECT             = LOCALVERSIONID
#
#     OBJECT                 = REPROCESSINGPLANNED
#       NUM_VAL              = 1
#       VALUE                = "further update is anticipated"
#     END_OBJECT             = REPROCESSINGPLANNED
#
#   END_GROUP              = ECSDATAGRANULE
#
#   GROUP                  = MEASUREDPARAMETER
#
#     OBJECT                 = MEASUREDPARAMETERCONTAINER
#       CLASS                = "1"
#
#       GROUP                  = QAFLAGS
#         CLASS                = "1"
#
#         OBJECT                 = SCIENCEQUALITYFLAG
#           NUM_VAL              = 1
#           VALUE                = "Not Investigated"
#           CLASS                = "1"
#         END_OBJECT             = SCIENCEQUALITYFLAG
#
#         OBJECT                 = AUTOMATICQUALITYFLAGEXPLANATION
#           NUM_VAL              = 1
#           CLASS                = "1"
#           VALUE                = "Set to 'Failed' if processing error occurred, set to 'Passed' otherwise"
#         END_OBJECT             = AUTOMATICQUALITYFLAGEXPLANATION
#
#         OBJECT                 = AUTOMATICQUALITYFLAG
#           NUM_VAL              = 1
#           CLASS                = "1"
#           VALUE                = "Passed"
#         END_OBJECT             = AUTOMATICQUALITYFLAG
#
#       END_GROUP              = QAFLAGS
#
#       GROUP                  = QASTATS
#         CLASS                = "1"
#
#         OBJECT                 = QAPERCENTMISSINGDATA
#           NUM_VAL              = 1
#           CLASS                = "1"
#           VALUE                = 0
#         END_OBJECT             = QAPERCENTMISSINGDATA
#
#         OBJECT                 = QAPERCENTOUTOFBOUNDSDATA
#           NUM_VAL              = 1
#           CLASS                = "1"
#           VALUE                = 0
#         END_OBJECT             = QAPERCENTOUTOFBOUNDSDATA
#
#       END_GROUP              = QASTATS
#
#       OBJECT                 = PARAMETERNAME
#         CLASS                = "1"
#         NUM_VAL              = 1
#         VALUE                = "Geolocation"
#       END_OBJECT             = PARAMETERNAME
#
#     END_OBJECT             = MEASUREDPARAMETERCONTAINER
#
#   END_GROUP              = MEASUREDPARAMETER
#
#   GROUP                  = ORBITCALCULATEDSPATIALDOMAIN
#
#     OBJECT                 = ORBITCALCULATEDSPATIALDOMAINCONTAINER
#       CLASS                = "1"
#
#       OBJECT                 = EQUATORCROSSINGDATE
#         CLASS                = "1"
#         NUM_VAL              = 1
#         VALUE                = "2005-07-18"
#       END_OBJECT             = EQUATORCROSSINGDATE
#
#       OBJECT                 = EQUATORCROSSINGTIME
#         CLASS                = "1"
#         NUM_VAL              = 1
#         VALUE                = "02:25:52.983227"
#       END_OBJECT             = EQUATORCROSSINGTIME
#
#       OBJECT                 = ORBITNUMBER
#         CLASS                = "1"
#         NUM_VAL              = 1
#         VALUE                = 29689
#       END_OBJECT             = ORBITNUMBER
#
#       OBJECT                 = EQUATORCROSSINGLONGITUDE
#         CLASS                = "1"
#         NUM_VAL              = 1
#         VALUE                = 120.831228315328
#       END_OBJECT             = EQUATORCROSSINGLONGITUDE
#
#     END_OBJECT             = ORBITCALCULATEDSPATIALDOMAINCONTAINER
#
#   END_GROUP              = ORBITCALCULATEDSPATIALDOMAIN
#
#   GROUP                  = COLLECTIONDESCRIPTIONCLASS
#
#     OBJECT                 = VERSIONID
#       NUM_VAL              = 1
#       VALUE                = 5
#     END_OBJECT             = VERSIONID
#
#     OBJECT                 = SHORTNAME
#       NUM_VAL              = 1
#       VALUE                = "MOD03"
#     END_OBJECT             = SHORTNAME
#
#   END_GROUP              = COLLECTIONDESCRIPTIONCLASS
#
#   GROUP                  = INPUTGRANULE
#
#     OBJECT                 = INPUTPOINTER
#       NUM_VAL              = 6
#       VALUE                = ("MOD01.20.2005-199T02:15:00.000000Z.NA.11348118.500100_1.hdf", "MOD03LUT.coeff_V5.0.40.6", "AM1EPHN0.A2005199.0200.001.2005199044151", "AM1ATTN0.A2005199.0200.001.2005199044151")
#     END_OBJECT             = INPUTPOINTER
#
#   END_GROUP              = INPUTGRANULE
#
#   GROUP                  = SPATIALDOMAINCONTAINER
#
#     GROUP                  = HORIZONTALSPATIALDOMAINCONTAINER
#
#       GROUP                  = GPOLYGON
#
#         OBJECT                 = GPOLYGONCONTAINER
#           CLASS                = "1"
#
#           GROUP                  = GRINGPOINT
#             CLASS                = "1"
#
#             OBJECT                 = GRINGPOINTLONGITUDE
#               NUM_VAL              = 4
#               CLASS                = "1"
#               VALUE                = (116.433573420253, 143.141943189611, 136.668621621617, 114.277891949334)
#             END_OBJECT             = GRINGPOINTLONGITUDE
#
#             OBJECT                 = GRINGPOINTLATITUDE
#               NUM_VAL              = 4
#               CLASS                = "1"
#               VALUE                = (40.5981062753567, 36.7425529616865, 19.2006244755836, 22.2670397235511)
#             END_OBJECT             = GRINGPOINTLATITUDE
#
#             OBJECT                 = GRINGPOINTSEQUENCENO
#               NUM_VAL              = 4
#               CLASS                = "1"
#               VALUE                = (1, 2, 3, 4)
#             END_OBJECT             = GRINGPOINTSEQUENCENO
#
#           END_GROUP              = GRINGPOINT
#
#           GROUP                  = GRING
#             CLASS                = "1"
#
#             OBJECT                 = EXCLUSIONGRINGFLAG
#               NUM_VAL              = 1
#               CLASS                = "1"
#               VALUE                = "N"
#             END_OBJECT             = EXCLUSIONGRINGFLAG
#
#           END_GROUP              = GRING
#
#         END_OBJECT             = GPOLYGONCONTAINER
#
#       END_GROUP              = GPOLYGON
#
#     END_GROUP              = HORIZONTALSPATIALDOMAINCONTAINER
#
#   END_GROUP              = SPATIALDOMAINCONTAINER
#
#   GROUP                  = RANGEDATETIME
#
#     OBJECT                 = RANGEENDINGDATE
#       NUM_VAL              = 1
#       VALUE                = "2005-07-18"
#     END_OBJECT             = RANGEENDINGDATE
#
#     OBJECT                 = RANGEENDINGTIME
#       NUM_VAL              = 1
#       VALUE                = "02:20:00.000000"
#     END_OBJECT             = RANGEENDINGTIME
#
#     OBJECT                 = RANGEBEGINNINGDATE
#       NUM_VAL              = 1
#       VALUE                = "2005-07-18"
#     END_OBJECT             = RANGEBEGINNINGDATE
#
#     OBJECT                 = RANGEBEGINNINGTIME
#       NUM_VAL              = 1
#       VALUE                = "02:15:00.000000"
#     END_OBJECT             = RANGEBEGINNINGTIME
#
#   END_GROUP              = RANGEDATETIME
#
#   GROUP                  = ASSOCIATEDPLATFORMINSTRUMENTSENSOR
#
#     OBJECT                 = ASSOCIATEDPLATFORMINSTRUMENTSENSORCONTAINER
#       CLASS                = "1"
#
#       OBJECT                 = ASSOCIATEDSENSORSHORTNAME
#         CLASS                = "1"
#         NUM_VAL              = 1
#         VALUE                = "MODIS"
#       END_OBJECT             = ASSOCIATEDSENSORSHORTNAME
#
#       OBJECT                 = ASSOCIATEDPLATFORMSHORTNAME
#         CLASS                = "1"
#         NUM_VAL              = 1
#         VALUE                = "Terra"
#       END_OBJECT             = ASSOCIATEDPLATFORMSHORTNAME
#
#       OBJECT                 = ASSOCIATEDINSTRUMENTSHORTNAME
#         CLASS                = "1"
#         NUM_VAL              = 1
#         VALUE                = "MODIS"
#       END_OBJECT             = ASSOCIATEDINSTRUMENTSHORTNAME
#
#     END_OBJECT             = ASSOCIATEDPLATFORMINSTRUMENTSENSORCONTAINER
#
#   END_GROUP              = ASSOCIATEDPLATFORMINSTRUMENTSENSOR
#
#   GROUP                  = PGEVERSIONCLASS
#
#     OBJECT                 = PGEVERSION
#       NUM_VAL              = 1
#       VALUE                = "5.0.40"
#     END_OBJECT             = PGEVERSION
#
#   END_GROUP              = PGEVERSIONCLASS
#
#   GROUP                  = ADDITIONALATTRIBUTES
#
#     OBJECT                 = ADDITIONALATTRIBUTESCONTAINER
#       CLASS                = "1"
#
#       OBJECT                 = ADDITIONALATTRIBUTENAME
#         CLASS                = "1"
#         NUM_VAL              = 1
#         VALUE                = "GRANULENUMBER"
#       END_OBJECT             = ADDITIONALATTRIBUTENAME
#
#       GROUP                  = INFORMATIONCONTENT
#         CLASS                = "1"
#
#         OBJECT                 = PARAMETERVALUE
#           NUM_VAL              = 1
#           CLASS                = "1"
#           VALUE                = "29"
#         END_OBJECT             = PARAMETERVALUE
#
#       END_GROUP              = INFORMATIONCONTENT
#
#     END_OBJECT             = ADDITIONALATTRIBUTESCONTAINER
#
#     OBJECT                 = ADDITIONALATTRIBUTESCONTAINER
#       CLASS                = "2"
#
#       OBJECT                 = ADDITIONALATTRIBUTENAME
#         CLASS                = "2"
#         NUM_VAL              = 1
#         VALUE                = "SCI_STATE"
#       END_OBJECT             = ADDITIONALATTRIBUTENAME
#
#       GROUP                  = INFORMATIONCONTENT
#         CLASS                = "2"
#
#         OBJECT                 = PARAMETERVALUE
#           NUM_VAL              = 1
#           CLASS                = "2"
#           VALUE                = "1"
#         END_OBJECT             = PARAMETERVALUE
#
#       END_GROUP              = INFORMATIONCONTENT
#
#     END_OBJECT             = ADDITIONALATTRIBUTESCONTAINER
#
#     OBJECT                 = ADDITIONALATTRIBUTESCONTAINER
#       CLASS                = "3"
#
#       OBJECT                 = ADDITIONALATTRIBUTENAME
#         CLASS                = "3"
#         NUM_VAL              = 1
#         VALUE                = "SCI_ABNORM"
#       END_OBJECT             = ADDITIONALATTRIBUTENAME
#
#       GROUP                  = INFORMATIONCONTENT
#         CLASS                = "3"
#
#         OBJECT                 = PARAMETERVALUE
#           NUM_VAL              = 1
#           CLASS                = "3"
#           VALUE                = "1"
#         END_OBJECT             = PARAMETERVALUE
#
#       END_GROUP              = INFORMATIONCONTENT
#
#     END_OBJECT             = ADDITIONALATTRIBUTESCONTAINER
#
#     OBJECT                 = ADDITIONALATTRIBUTESCONTAINER
#       CLASS                = "5"
#
#       OBJECT                 = ADDITIONALATTRIBUTENAME
#         CLASS                = "5"
#         NUM_VAL              = 1
#         VALUE                = "PROCESSVERSION"
#       END_OBJECT             = ADDITIONALATTRIBUTENAME
#
#       GROUP                  = INFORMATIONCONTENT
#         CLASS                = "5"
#
#         OBJECT                 = PARAMETERVALUE
#           NUM_VAL              = 1
#           CLASS                = "5"
#           VALUE                = "5.0.13"
#         END_OBJECT             = PARAMETERVALUE
#
#       END_GROUP              = INFORMATIONCONTENT
#
#     END_OBJECT             = ADDITIONALATTRIBUTESCONTAINER
#
#     OBJECT                 = ADDITIONALATTRIBUTESCONTAINER
#       CLASS                = "4"
#
#       OBJECT                 = ADDITIONALATTRIBUTENAME
#         CLASS                = "4"
#         NUM_VAL              = 1
#         VALUE                = "GEO_EST_RMS_ERROR"
#       END_OBJECT             = ADDITIONALATTRIBUTENAME
#
#       GROUP                  = INFORMATIONCONTENT
#         CLASS                = "4"
#
#         OBJECT                 = PARAMETERVALUE
#           NUM_VAL              = 1
#           CLASS                = "4"
#           VALUE                = "50      "
#         END_OBJECT             = PARAMETERVALUE
#
#       END_GROUP              = INFORMATIONCONTENT
#
#     END_OBJECT             = ADDITIONALATTRIBUTESCONTAINER
#
#   END_GROUP              = ADDITIONALATTRIBUTES
#
# END_GROUP              = INVENTORYMETADATA
#
# END
#
# attribute name:  ArchiveMetadata.0_GLOSDS --- value:
# GROUP                  = ARCHIVEDMETADATA
#   GROUPTYPE            = MASTERGROUP
#
#   OBJECT                 = LOCALINPUTGRANULEID
#     NUM_VAL              = 1
#     VALUE                = "MOD01.A2005199.0215.005.2010154180039.hdf"
#   END_OBJECT             = LOCALINPUTGRANULEID
#
#   OBJECT                 = EASTBOUNDINGCOORDINATE
#     NUM_VAL              = 1
#     VALUE                = 143.137892890731
#   END_OBJECT             = EASTBOUNDINGCOORDINATE
#
#   OBJECT                 = NORTHBOUNDINGCOORDINATE
#     NUM_VAL              = 1
#     VALUE                = 40.5748185071311
#   END_OBJECT             = NORTHBOUNDINGCOORDINATE
#
#   OBJECT                 = SOUTHBOUNDINGCOORDINATE
#     NUM_VAL              = 1
#     VALUE                = 19.2607264596942
#   END_OBJECT             = SOUTHBOUNDINGCOORDINATE
#
#   OBJECT                 = WESTBOUNDINGCOORDINATE
#     NUM_VAL              = 1
#     VALUE                = 114.300862009532
#   END_OBJECT             = WESTBOUNDINGCOORDINATE
#
#   OBJECT                 = DESCRREVISION
#     NUM_VAL              = 1
#     VALUE                = "5.0"
#   END_OBJECT             = DESCRREVISION
#
#   OBJECT                 = PRODUCTIONHISTORY
#     NUM_VAL              = 1
#     VALUE                = "PGE01:5.0.40"
#   END_OBJECT             = PRODUCTIONHISTORY
#
#   OBJECT                 = LONGNAME
#     NUM_VAL              = 1
#     VALUE                = "MODIS/Terra Geolocation Fields 5-Min L1A Swath 1km"
#   END_OBJECT             = LONGNAME
#
#   OBJECT                 = PROCESSINGENVIRONMENT
#     NUM_VAL              = 1
#     VALUE                = "Linux minion5388 2.6.22.19-server-2mdv #1 SMP Mon May 5 21:13:00 EDT 2008 i686 Intel(R) Xeon(R) CPU           E5430  @ 2.66GHz GNU/Linux"
#   END_OBJECT             = PROCESSINGENVIRONMENT
#
# END_GROUP              = ARCHIVEDMETADATA
#
# END
#
# attribute name:  Number of Scans_GLOSDS --- value:  204
# attribute name:  Max Earth Frames_GLOSDS --- value:  1354
# attribute name:  Max SD Frames_GLOSDS --- value:  50
# attribute name:  Max SV Frames_GLOSDS --- value:  50
# attribute name:  Incomplete Scans_GLOSDS --- value:  0
# attribute name:  Missing Packets_GLOSDS --- value:  0
# attribute name:  Packets with bad CRC_GLOSDS --- value:  0
# attribute name:  Discarded Packets_GLOSDS --- value:  0
# attribute name:  Ephemeris/Attitude Source_GLOSDS --- value:  SDP Toolkit
# attribute name:  Parameter Version_GLOSDS --- value:  5.10.1.1
# attribute name:  GEO_EST_RMS_ERROR_GLOSDS --- value:  50.0
# attribute name:  Maneuver File Version_GLOSDS --- value:  5.62.1.14
# attribute name:  Cumulated gflags_GLOSDS --- value:  [0 0 0 0 0 0 0 0]
# attribute name:  utcpole File Header_GLOSDS --- value:  File Updated: 2010-05-07T01:59:39Z, using USNO ser7 finals.data file of May  06
# attribute name:  Polar Motion_GLOSDS --- value:  [-0.019711    0.4150493  -0.60642136]
# attribute name:  NOT EMPTY19622_GLOSDS --- value:  NOT EMPTY

# %%
the_long=geom_h5['MODIS_Swath_Type_GEO']['Geolocation Fields']['Longitude'][...]
the_lat=geom_h5['MODIS_Swath_Type_GEO']['Geolocation Fields']['Latitude'][...]

# %%
print(the_long.shape,the_lat.shape)
# Out:
# (2040L, 1354L) (2040L, 1354L)

# %%
print('===================================================')
print('Size of Longitude: {}'.format(the_long.shape))
print('Longitude Range: {} ~ {}'.format(np.min(the_long), np.max(the_long)))
print('===================================================')
print('Size of Latitude: {}'.format(the_lat.shape))
print('Latitude Range: {} ~ {}'.format(np.min(the_lat), np.max(the_lat)))
# Out:
# ===================================================
# Size of Longitude: (2040L, 1354L)
# Longitude Range: 114.300865173 ~ 143.137893677
# ===================================================
# Size of Latitude: (2040L, 1354L)
# Latitude Range: 19.2607269287 ~ 40.5748176575

# %%
def reproj_L1B(raw_data, raw_x, raw_y, xlim, ylim, res):
    
    '''
    =========================================================================================
    Reproject MODIS L1B file to a regular grid
    -----------------------------------------------------------------------------------------
    d_array, x_array, y_array, bin_count = reproj_L1B(raw_data, raw_x, raw_y, xlim, ylim, res)
    -----------------------------------------------------------------------------------------
    Input:
            raw_data: L1B data, N*M 2-D array.
            raw_x: longitude info. N*M 2-D array.
            raw_y: latitude info. N*M 2-D array.
            xlim: range of longitude, a list.
            ylim: range of latitude, a list.
            res: resolution, single value.
    Output:
            d_array: L1B reprojected data.
            x_array: reprojected longitude.
            y_array: reprojected latitude.
            bin_count: how many raw data point included in a reprojected grid.
    Note:
            function do not performs well if "res" is larger than the resolution of input data.
            size of "raw_data", "raw_x", "raw_y" must agree.
    =========================================================================================
    '''
    
    
    x_bins=np.arange(xlim[0], xlim[1], res)
    y_bins=np.arange(ylim[0], ylim[1], res)
#    x_indices=np.digitize(raw_x.flat, x_bins)
#    y_indices=np.digitize(raw_y.flat, y_bins)
    x_indices=np.searchsorted(x_bins, raw_x.flat, 'right')
    y_indices=np.searchsorted(y_bins, raw_y.flat, 'right')
        
    y_array=np.zeros([len(y_bins), len(x_bins)], dtype=np.float)
    x_array=np.zeros([len(y_bins), len(x_bins)], dtype=np.float)
    d_array=np.zeros([len(y_bins), len(x_bins)], dtype=np.float)
    bin_count=np.zeros([len(y_bins), len(x_bins)], dtype=np.int)
    
    for n in range(len(y_indices)): #indices
        bin_row=y_indices[n]-1 # '-1' is because we call 'right' in np.searchsorted.
        bin_col=x_indices[n]-1
        bin_count[bin_row, bin_col] += 1
        x_array[bin_row, bin_col] += raw_x.flat[n]
        y_array[bin_row, bin_col] += raw_y.flat[n]
        d_array[bin_row, bin_col] += raw_data.flat[n]
                   
    for i in range(x_array.shape[0]):
        for j in range(x_array.shape[1]):
            if bin_count[i, j] > 0:
                x_array[i, j]=x_array[i, j]/bin_count[i, j]
                y_array[i, j]=y_array[i, j]/bin_count[i, j]
                d_array[i, j]=d_array[i, j]/bin_count[i, j] 
            else:
                d_array[i, j]=np.nan
                x_array[i, j]=np.nan
                y_array[i,j]=np.nan
                
    return d_array, x_array, y_array, bin_count

# %% [markdown]
# **now regrid the radiances and brightness temperatures on a 0.1 x 0.1 degree regular lat/lon grid**

# %%
xlim=[np.min(the_long), np.max(the_long)]
ylim=[np.min(the_lat), np.max(the_lat)]
chan31_grid, longitude, latitude, bin_count = reproj_L1B(chan31, the_long, the_lat, xlim, ylim, 0.1)
tbright_grid,longitude,latitude,bin_count=reproj_L1B(chan31_Tbright, the_long, the_lat, xlim, ylim, 0.1)

# %%
chan31_grid=np.ma.masked_where(np.isnan(chan31_grid), chan31_grid)
bin_count=np.ma.masked_where(np.isnan(bin_count), bin_count)
longitude=np.ma.masked_where(np.isnan(longitude), longitude)
latitude=np.ma.masked_where(np.isnan(latitude), latitude)
longitude.shape
# Out:
# (214L, 289L)

# %% [markdown]
# **Plot this gridded data without a map projections**

# %%
fig=plt.figure(figsize=(10.5, 9.5))
ax=fig.add_subplot(111)
ax.set_xlim(xlim[0], xlim[1])
ax.set_ylim(ylim[0], ylim[1])
image=ax.pcolormesh(longitude, latitude, chan31_grid)

# %% [markdown]
# Typhoon Haitang July 18th, 2005.

# %% [markdown]
# **Now replot using an lcc (Lambert conformal conic) projection from basemap** at http://matplotlib.org/basemap/users/examples.html

# %%
from mpl_toolkits.basemap import Basemap

# %%
lcc_values=dict(resolution='l',projection='lcc',
                lat_1=20,lat_2=40,lat_0=30,lon_0=135,
                llcrnrlon=120,llcrnrlat=20,
                urcrnrlon=150,urcrnrlat=42)

# %%
proj=Basemap(**lcc_values)

# %%
# create figure, add axes
fig=plt.figure(figsize=(12, 12))
ax=fig.add_subplot(111)
## define parallels and meridians to draw.
parallels=np.arange(-90, 90, 5)
meridians=np.arange(0, 360, 5)
proj.drawparallels(parallels, labels=[1, 0, 0, 0],\
                  fontsize=10, latmax=90)
proj.drawmeridians(meridians, labels=[0, 0, 0, 1],\
                  fontsize=10, latmax=90)
# draw coast & fill continents
#map.fillcontinents(color=[0.25, 0.25, 0.25], lake_color=None) # coral
out=proj.drawcoastlines(linewidth=1.5, linestyle='solid', color='k')
x, y=proj(longitude, latitude)
# contourf the bathmetry
CS=proj.pcolor(x, y, chan31_grid, cmap=plt.cm.hot)
# colorbar
CBar=proj.colorbar(CS, 'right', size='5%', pad='5%')
CBar.set_label('Channel 31 radiance ($W\,m^{-2}\,\mu m\,sr^{-1})$', fontsize=10)
CBar.ax.tick_params(axis='y', length=0)

# %% [markdown]
# Typhoon Haitang July 18th, 2005.

# %% [markdown]
# **repeat for brightness temperature**

# %%
# create figure, add axes
fig=plt.figure(figsize=(12, 12))
ax=fig.add_subplot(111)
## define parallels and meridians to draw.
parallels=np.arange(-90, 90, 5)
meridians=np.arange(0, 360, 5)
proj.drawparallels(parallels, labels=[1, 0, 0, 0],\
                  fontsize=10, latmax=90)
proj.drawmeridians(meridians, labels=[0, 0, 0, 1],\
                  fontsize=10, latmax=90)
# draw coast & fill continents
#map.fillcontinents(color=[0.25, 0.25, 0.25], lake_color=None) # coral
out=proj.drawcoastlines(linewidth=1.5, linestyle='solid', color='k')
x, y=proj(longitude, latitude)
# contourf the bathmetry
CS=proj.pcolor(x, y, tbright_grid, cmap=plt.cm.hot)
# colorbar
CBar=proj.colorbar(CS, 'right', size='5%', pad='5%')
CBar.set_label('Channel 31 Brightness temperature (K)', fontsize=10)
CBar.ax.tick_params(axis='y', length=0)

# %% [markdown]
# Typhoon Haitang July 18th, 2005.
